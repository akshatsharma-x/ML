# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatsharma-x/ML/blob/main/Lab_4a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Contacts (3).vcf',
#  'Akshat Sharma (1).vcf',
#  '2017-04-04_11.46.04.jpg',
#  '2017-04-04_11.16.28.jpg',
#  'Photo Collage_1484053271333.png',
#  'Photo Collage_1484191896103.png',
#  'Photo Collage_1485592182546.png',
#  'IMG-20170318-WA0004.jpg',
#  'IMG-20170403-WA0000.jpg',
#  'IMG-20170403-WA0001.jpg',
#  '2017-03-22 14.57.50.jpg',
#  'IMG-20170318-WA0003.jpg',
#  'IMG-20170308-WA0007.jpg',
#  'IMG-20170318-WA0002.jpg',
#  '2017-03-18 15.29.37.jpg',
#  'IMG-20170308-WA0004.jpg',
#  'IMG-20170308-WA0002.jpg',
#  'IMG-20170308-WA0001.jpg',
#  'IMG-20170226-WA0001.jpg',
#  'IMG-20170226-WA0000.jpg',
#  'IMG-20170108-WA0001.jpg',
#  'IMG-20170108-WA0001-1.jpg',
#  'B612_20170404_212744.jpg',
#  'B612_20170404_213045.jpg',
#  'B612_20170404_212804.jpg',
#  'B612_20170404_213055.jpg',
#  'B612_20161231_221941.jpg',
#  'B612_20161231_222115.jpg',
#  'B612_20161231_222730.jpg',
#  'B612_20161231_221931.jpg',
#  'B612_20161231_210016.jpg',
#  'B612_20161231_204758.jpg',
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.head(15))
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
df.shape
# Out:
# (150, 6)

# %%
print(df.shape)
# Out:
# (150, 6)

# %%
print(df.tail())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
print(df.tail(15))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# ...

# %%
print(df.loc[140])
# Out:
# Id                          141
# SepalLengthCm               6.7
# SepalWidthCm                3.1
# PetalLengthCm               5.6
# PetalWidthCm                2.4
# Species          Iris-virginica
# Name: 140, dtype: object

# %%
print(df.loc[[0,99,140]])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 99   100            5.7           2.8            4.1           1.3
# 140  141            6.7           3.1            5.6           2.4
#
#              Species
# 0        Iris-setosa
# 99   Iris-versicolor
# 140   Iris-virginica

# %%
print(df.iloc[-1])
# Out:
# Id                          150
# SepalLengthCm               5.9
# SepalWidthCm                3.0
# PetalLengthCm               5.1
# PetalWidthCm                1.8
# Species          Iris-virginica
# Name: 149, dtype: object

# %%
print(df.iloc[[0,99,140]])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 99   100            5.7           2.8            4.1           1.3
# 140  141            6.7           3.1            5.6           2.4
#
#              Species
# 0        Iris-setosa
# 99   Iris-versicolor
# 140   Iris-virginica

# %%
subset = df.loc[:, ['SepalLengthCm']]
print(subset.head())
# Out:
#    SepalLengthCm
# 0            5.1
# 1            4.9
# 2            4.7
# 3            4.6
# 4            5.0

# %%
subset2 = df.iloc[:, [2,4]]
print(subset2.head())
# Out:
#    SepalWidthCm  PetalWidthCm
# 0           3.5           0.2
# 1           3.0           0.2
# 2           3.2           0.2
# 3           3.1           0.2
# 4           3.6           0.2

# %%
subset2 = df.iloc[:, [2,4,-1]]
print(subset2.head())
# Out:
#    SepalWidthCm  PetalWidthCm      Species
# 0           3.5           0.2  Iris-setosa
# 1           3.0           0.2  Iris-setosa
# 2           3.2           0.2  Iris-setosa
# 3           3.1           0.2  Iris-setosa
# 4           3.6           0.2  Iris-setosa

# %%
list1 = list(range(5))
print(list1)
# Out:
# [0, 1, 2, 3, 4]

# %%
subset3 = df.iloc[:,list1]
print(subset3.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
print(df.loc[20,'SepalWidthCm'])
print(df.iloc[20,1])
# Out:
# 3.4
# 5.4

# %%
print(df.iloc[[0,99,149],[0,3,5]])
# Out:
#       Id  PetalLengthCm          Species
# 0      1            1.4      Iris-setosa
# 99   100            4.1  Iris-versicolor
# 149  150            5.1   Iris-virginica

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(df.notnull().sum())
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.loc[10:15,'SepalLengthCm'] = np.nan
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    6
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.loc[20:25,'PetalLengthCm'] = np.nan
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    6
# SepalWidthCm     0
# PetalLengthCm    6
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean(), inplace=True)
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    6
# PetalWidthCm     0
# Species          0
# dtype: int64
# /tmp/ipython-input-2106090327.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean(), inplace=True)

# %%
df['PetalWidthCm'].fillna(df['PetalWidthCm'].median(), inplace=True)
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    6
# PetalWidthCm     0
# Species          0
# dtype: int64
# /tmp/ipython-input-1932850716.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PetalWidthCm'].fillna(df['PetalWidthCm'].median(), inplace=True)

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.rename(columns={'SepalLengthCm':'SL','PetalWidthCm':'PW'}, inplace=True)
print(df.head)
# Out:
# <bound method NDFrame.head of       Id   SL  SepalWidthCm  PetalLengthCm   PW         Species
# 0      1  5.1           3.5            1.4  0.2     Iris-setosa
# 1      2  4.9           3.0            1.4  0.2     Iris-setosa
# 2      3  4.7           3.2            1.3  0.2     Iris-setosa
# 3      4  4.6           3.1            1.5  0.2     Iris-setosa
# 4      5  5.0           3.6            1.4  0.2     Iris-setosa
# ..   ...  ...           ...            ...  ...             ...
# 145  146  6.7           3.0            5.2  2.3  Iris-virginica
# 146  147  6.3           2.5            5.0  1.9  Iris-virginica
# 147  148  6.5           3.0            5.2  2.0  Iris-virginica
# 148  149  6.2           3.4            5.4  2.3  Iris-virginica
# 149  150  5.9           3.0            5.1  1.8  Iris-virginica
#
# [144 rows x 6 columns]>

# %%
print(df.columns)
# Out:
# Index(['Id', 'SL', 'SepalWidthCm', 'PetalLengthCm', 'PW', 'Species'], dtype='object')

# %%
df["SL"] = df["SL"].astype(float)
df["PW"] = df["PW"].astype(float)

# %%
df['Species'].replace({"Iris_setosa":0,"Iris.versicolor":1,"Iris.virginica":2},inplace=True)
# Out:
# /tmp/ipython-input-2813238340.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Species'].replace({"Iris_setosa":0,"Iris.versicolor":1,"Iris.virginica":2},inplace=True)

# %%
# Evaluate Linear Regression Model
print("LINEAR REGRESSION EVALUATION")
print("Mean Squared Error:", mean_squared_error(y_test_lr, y_pred_lr))
print("Mean Absolute Error:", mean_absolute_error(y_test_lr, y_pred_lr))
print("R2 Score:", r2_score(y_test_lr, y_pred_lr))
# Out:
# LINEAR REGRESSION EVALUATION
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3921234882.py in <cell line: 0>()
#       1 # Evaluate Linear Regression Model
#       2 print("LINEAR REGRESSION EVALUATION")
# ----> 3 print("Mean Squared Error:", mean_squared_error(y_test_lr, y_pred_lr))
#       4 print("Mean Absolute Error:", mean_absolute_error(y_test_lr, y_pred_lr))
#       5 print("R2 Score:", r2_score(y_test_lr, y_pred_lr))
#
# NameError: name 'mean_squared_error' is not defined
